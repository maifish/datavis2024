# %% [markdown]
# <a href="https://colab.research.google.com/github/maifish/datavis2024/blob/main/JO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('projet_datavis2024_jo.csv')

fig = px.line(df, x = 'year', y = 'athletes', title='Nb athletes a travers des JO')
#fig = px.pie(df, values='age', names='film_titre', title="Films CEN")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
